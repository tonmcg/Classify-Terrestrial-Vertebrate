# %%
# https://github.com/rasbt/watermark
# %load_ext watermark
# %watermark -u -n -v -p pandas,numpy,exifread -m

import exifread as ex
import pandas as pd
import numpy as np

import os

SPECIES_CLASSES = ['Loxodonta']
# Out:
# last updated: Wed Feb 01 2017
#
# CPython 3.5.2
# IPython 5.1.0
#
# pandas 0.19.1
# numpy 1.11.2
# exifread 2.1.2
#
# compiler   : GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)
# system     : Darwin
# release    : 14.5.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 4
# interpreter: 64bit

# %%
def get_tags(directory, species, filetype, random=0):
    """Load files from directory folder"""
    """Use os.walk() traversal method"""
    image_data = []
    for root, dirs, files in os.walk(directory+species):
        for file in files:
            if file.endswith(filetype):
                f = open(os.path.join(root,file),'rb')
                tags = ex.process_file(f)
                image_data.extend([tags])
    return image_data

# %%
# get all image metadata for each species

# define images directory
DROPBOX = "/Users/Luxive/Dropbox/TEAM_Machine Learning/"
DROPBOX = '/Users/Luxive/Desktop'

SPECIES_CLASSES = ['photos']
for species in SPECIES_CLASSES:
    images_data = get_tags(DROPBOX,species,".JPG")

df = pd.DataFrame(images_data)
df
# Out:
#       EXIF ColorSpace EXIF ComponentsConfiguration EXIF CustomRendered  \
# 0                sRGB                        YCbCr                 NaN
# 1                sRGB                        YCbCr                 NaN
# 2                sRGB                        YCbCr                 NaN
# 3                sRGB                        YCbCr                 NaN
# 4                sRGB                        YCbCr                 NaN
# 5                sRGB                        YCbCr                 NaN
# 6                sRGB                        YCbCr                 NaN
# 7                sRGB                        YCbCr                 NaN
# 8                sRGB                        YCbCr                 NaN
# 9                sRGB                        YCbCr                 NaN
# 10               sRGB                        YCbCr                 NaN
# 11               sRGB                        YCbCr                 NaN
# 12               sRGB                        YCbCr                 NaN
# 13               sRGB                        YCbCr                 NaN
# 14               sRGB                        YCbCr                 NaN
# 15               sRGB                        YCbCr                 NaN
# 16               sRGB                        YCbCr                 NaN
# 17               sRGB                        YCbCr                 NaN
# 18               sRGB                        YCbCr                 NaN
# 19               sRGB                        YCbCr                 NaN
# 20               sRGB                        YCbCr                 NaN
# 21               sRGB                        YCbCr                 NaN
# 22               sRGB                        YCbCr                 NaN
# 23               sRGB                        YCbCr                 NaN
# 24               sRGB                        YCbCr                 NaN
# 25               sRGB                        YCbCr                 NaN
# 26               sRGB                        YCbCr                 NaN
# 27               sRGB                        YCbCr                 NaN
# 28               sRGB                        YCbCr                 NaN
# 29               sRGB                        YCbCr                 NaN
# ...               ...                          ...                 ...
# 31385            sRGB                        YCbCr              Normal
# 31386            sRGB                        YCbCr              Normal
# 31387            sRGB                        YCbCr              Normal
# 31388            sRGB                        YCbCr              Normal
# 31389            sRGB                        YCbCr              Normal
# 31390            sRGB                        YCbCr              Normal
# 31391            sRGB                        YCbCr              Normal
# 31392            sRGB                        YCbCr              Normal
# 31393            sRGB                        YCbCr              Normal
# 31394            sRGB                        YCbCr              Normal
# 31395            sRGB                        YCbCr              Normal
# 31396            sRGB                        YCbCr              Normal
# 31397            sRGB                        YCbCr              Normal
# 31398            sRGB                        YCbCr              Normal
# 31399            sRGB                        YCbCr              Normal
# 31400            sRGB                        YCbCr              Normal
# 31401            sRGB                        YCbCr              Normal
# 31402            sRGB                        YCbCr              Normal
# 31403            sRGB                        YCbCr              Normal
# 31404            sRGB                        YCbCr              Normal
# 31405            sRGB                        YCbCr              Normal
# 31406            sRGB                        YCbCr              Normal
# 31407            sRGB                        YCbCr              Normal
# 31408            sRGB                        YCbCr              Normal
# 31409            sRGB                        YCbCr              Normal
# 31410            sRGB                        YCbCr              Normal
# 31411            sRGB                        YCbCr              Normal
# 31412            sRGB                        YCbCr              Normal
# 31413            sRGB                        YCbCr              Normal
# 31414            sRGB                        YCbCr              Normal
#
#       EXIF DateTimeDigitized EXIF DateTimeOriginal EXIF ExifImageLength  \
# 0                        NaN                   NaN                 1536
# 1                        NaN                   NaN                 1536
# 2                        NaN                   NaN                 1536
# 3                        NaN                   NaN                 1536
# 4                        NaN                   NaN                 1536
# 5                        NaN                   NaN                 1536
# 6                        NaN                   NaN                 1536
# 7                        NaN                   NaN                 1536
# 8                        NaN                   NaN                 1536
# 9                        NaN                   NaN                 1536
# 10                       NaN                   NaN                 1536
# 11                       NaN                   NaN                 1536
# 12                       NaN                   NaN                 1536
# 13                       NaN                   NaN                 1536
# 14                       NaN                   NaN                 1536
# 15                       NaN                   NaN                 1536
# 16                       NaN                   NaN                 1536
# 17                       NaN                   NaN                 1536
# 18                       NaN                   NaN                 1536
# 19                       NaN                   NaN                 1536
# 20                       NaN                   NaN                 1536
# 21                       NaN                   NaN                 1536
# 22                       NaN                   NaN                 1536
# 23                       NaN                   NaN                 1536
# 24                       NaN                   NaN                 1536
# 25                       NaN                   NaN                 1536
# 26                       NaN                   NaN                 1536
# 27                       NaN                   NaN                 1536
# 28                       NaN                   NaN                 1536
# 29                       NaN                   NaN                 1536
# ...                      ...                   ...                  ...
# 31385    2016:01:12 17:55:07   2016:01:12 17:55:07                 1024
# 31386    2016:01:12 17:55:08   2016:01:12 17:55:08                 1024
# 31387    2016:01:12 17:55:13   2016:01:12 17:55:13                 1024
# 31388    2016:01:12 17:55:14   2016:01:12 17:55:14                 1024
# 31389    2016:01:12 17:55:14   2016:01:12 17:55:14                 1024
# 31390    2016:01:12 17:55:15   2016:01:12 17:55:15                 1024
# 31391    2016:01:12 17:55:16   2016:01:12 17:55:16                 1024
# 31392    2016:01:12 17:55:17   2016:01:12 17:55:17                 1024
# 31393    2016:01:12 17:55:29   2016:01:12 17:55:29                 1024
# 31394    2016:01:12 17:55:30   2016:01:12 17:55:30                 1024
# 31395    2016:01:12 17:55:31   2016:01:12 17:55:31                 1024
# 31396    2016:01:12 17:55:32   2016:01:12 17:55:32                 1024
# 31397    2016:01:12 17:55:33   2016:01:12 17:55:33                 1024
# 31398    2016:01:12 17:55:34   2016:01:12 17:55:34                 1024
# 31399    2016:01:12 17:55:40   2016:01:12 17:55:40                 1024
# 31400    2016:01:12 17:55:41   2016:01:12 17:55:41                 1024
# 31401    2016:01:12 17:55:42   2016:01:12 17:55:42                 1024
# 31402    2016:01:12 17:55:44   2016:01:12 17:55:44                 1024
# 31403    2016:01:12 17:55:45   2016:01:12 17:55:45                 1024
# 31404    2016:01:12 17:55:46   2016:01:12 17:55:46                 1024
# 31405    2016:01:12 17:55:47   2016:01:12 17:55:47                 1024
# 31406    2016:01:12 17:55:48   2016:01:12 17:55:48                 1024
# 31407    2016:01:12 17:55:48   2016:01:12 17:55:48                 1024
# 31408    2016:01:12 17:55:58   2016:01:12 17:55:58                 1024
# 31409    2016:01:12 17:55:59   2016:01:12 17:55:59                 1024
# 31410    2016:01:12 17:56:00   2016:01:12 17:56:00                 1024
# 31411    2016:01:12 17:56:01   2016:01:12 17:56:01                 1024
# 31412    2016:01:12 17:56:02   2016:01:12 17:56:02                 1024
# 31413    2016:01:12 17:56:03   2016:01:12 17:56:03                 1024
# 31414    2016:01:12 17:56:04   2016:01:12 17:56:04                 1024
#
#       EXIF ExifImageWidth EXIF ExifVersion EXIF ExposureMode  \
# 0                    2048             0220               NaN
# 1                    2048             0220               NaN
# 2                    2048             0220               NaN
# 3                    2048             0220               NaN
# 4                    2048             0220               NaN
# 5                    2048             0220               NaN
# 6                    2048             0220               NaN
# 7                    2048             0220               NaN
# 8                    2048             0220               NaN
# 9                    2048             0220               NaN
# 10                   2048             0220               NaN
# 11                   2048             0220               NaN
# 12                   2048             0220               NaN
# 13                   2048             0220               NaN
# 14                   2048             0220               NaN
# 15                   2048             0220               NaN
# 16                   2048             0220               NaN
# 17                   2048             0220               NaN
# 18                   2048             0220               NaN
# 19                   2048             0220               NaN
# 20                   2048             0220               NaN
# 21                   2048             0220               NaN
# 22                   2048             0220               NaN
# 23                   2048             0220               NaN
# 24                   2048             0220               NaN
# 25                   2048             0220               NaN
# 26                   2048             0220               NaN
# 27                   2048             0220               NaN
# 28                   2048             0220               NaN
# 29                   2048             0220               NaN
# ...                   ...              ...               ...
# 31385                1280             0220     Auto Exposure
# 31386                1280             0220     Auto Exposure
# 31387                1280             0220     Auto Exposure
# 31388                1280             0220     Auto Exposure
# 31389                1280             0220     Auto Exposure
# 31390                1280             0220     Auto Exposure
# 31391                1280             0220     Auto Exposure
# 31392                1280             0220     Auto Exposure
# 31393                1280             0220     Auto Exposure
# 31394                1280             0220     Auto Exposure
# 31395                1280             0220     Auto Exposure
# 31396                1280             0220     Auto Exposure
# 31397                1280             0220     Auto Exposure
# 31398                1280             0220     Auto Exposure
# 31399                1280             0220     Auto Exposure
# 31400                1280             0220     Auto Exposure
# 31401                1280             0220     Auto Exposure
# 31402                1280             0220     Auto Exposure
# 31403                1280             0220     Auto Exposure
# 31404                1280             0220     Auto Exposure
# 31405                1280             0220     Auto Exposure
# 31406                1280             0220     Auto Exposure
# 31407                1280             0220     Auto Exposure
# 31408                1280             0220     Auto Exposure
# 31409                1280             0220     Auto Exposure
# 31410                1280             0220     Auto Exposure
# 31411                1280             0220     Auto Exposure
# 31412                1280             0220     Auto Exposure
# 31413                1280             0220     Auto Exposure
# 31414                1280             0220     Auto Exposure
#
#       EXIF ExposureTime        ...        EXIF SceneCaptureType  \
# 0                  1/30        ...                          NaN
# 1                  1/30        ...                          NaN
# 2                  1/30        ...                          NaN
# 3                  1/30        ...                          NaN
# 4                  1/30        ...                          NaN
# 5                  1/30        ...                          NaN
# 6                  1/30        ...                          NaN
# 7                  1/30        ...                          NaN
# 8                  1/30        ...                          NaN
# 9                  1/30        ...                          NaN
# 10                 1/30        ...                          NaN
# 11                 1/30        ...                          NaN
# 12                 1/30        ...                          NaN
# 13                 1/30        ...                          NaN
# 14                 1/30        ...                          NaN
# 15                 1/30        ...                          NaN
# 16                 1/30        ...                          NaN
# 17                 1/30        ...                          NaN
# 18                 1/30        ...                          NaN
# 19                 1/30        ...                          NaN
# 20                 1/30        ...                          NaN
# 21                 1/30        ...                          NaN
# 22                 1/30        ...                          NaN
# 23                 1/30        ...                          NaN
# 24                 1/30        ...                          NaN
# 25                 1/30        ...                          NaN
# 26                 1/30        ...                          NaN
# 27                 1/30        ...                          NaN
# 28                 1/30        ...                          NaN
# 29                 1/30        ...                          NaN
# ...                 ...        ...                          ...
# 31385              1/30        ...                       Night)
# 31386              1/30        ...                       Night)
# 31387              1/30        ...                       Night)
# 31388              1/30        ...                       Night)
# 31389              1/30        ...                       Night)
# 31390              1/30        ...                       Night)
# 31391              1/30        ...                       Night)
# 31392              1/30        ...                       Night)
# 31393              1/30        ...                       Night)
# 31394              1/30        ...                       Night)
# 31395              1/30        ...                       Night)
# 31396              1/30        ...                       Night)
# 31397              1/30        ...                       Night)
# 31398              1/30        ...                       Night)
# 31399              1/32        ...                       Night)
# 31400          139/6720        ...                       Night)
# 31401          139/6720        ...                       Night)
# 31402              1/60        ...                       Night)
# 31403              1/30        ...                       Night)
# 31404              1/30        ...                       Night)
# 31405              1/64        ...                       Night)
# 31406              1/64        ...                       Night)
# 31407              1/30        ...                       Night)
# 31408         349/13440        ...                       Night)
# 31409         349/13440        ...                       Night)
# 31410         349/13440        ...                       Night)
# 31411         271/13440        ...                       Night)
# 31412         271/13440        ...                       Night)
# 31413              1/60        ...                       Night)
# 31414           11/4480        ...                       Night)
#
#       EXIF WhiteBalance       Image DateTime Image ExifOffset Image Make  \
# 0                   NaN                  NaN               90        NaN
# 1                   NaN                  NaN               90        NaN
# 2                   NaN                  NaN               90        NaN
# 3                   NaN                  NaN               90        NaN
# 4                   NaN                  NaN               90        NaN
# 5                   NaN                  NaN               90        NaN
# 6                   NaN                  NaN               90        NaN
# 7                   NaN                  NaN               90        NaN
# 8                   NaN                  NaN               90        NaN
# 9                   NaN                  NaN               90        NaN
# 10                  NaN                  NaN               90        NaN
# 11                  NaN                  NaN               90        NaN
# 12                  NaN                  NaN               90        NaN
# 13                  NaN                  NaN               90        NaN
# 14                  NaN                  NaN               90        NaN
# 15                  NaN                  NaN               90        NaN
# 16                  NaN                  NaN               90        NaN
# 17                  NaN                  NaN               90        NaN
# 18                  NaN                  NaN               90        NaN
# 19                  NaN                  NaN               90        NaN
# 20                  NaN                  NaN               90        NaN
# 21                  NaN                  NaN               90        NaN
# 22                  NaN                  NaN               90        NaN
# 23                  NaN                  NaN               90        NaN
# 24                  NaN                  NaN               90        NaN
# 25                  NaN                  NaN               90        NaN
# 26                  NaN                  NaN               90        NaN
# 27                  NaN                  NaN               90        NaN
# 28                  NaN                  NaN               90        NaN
# 29                  NaN                  NaN               90        NaN
# ...                 ...                  ...              ...        ...
# 31385              Auto  2016:01:12 17:55:07              186  Reconyx
# 31386              Auto  2016:01:12 17:55:08              186  Reconyx
# 31387              Auto  2016:01:12 17:55:13              186  Reconyx
# 31388              Auto  2016:01:12 17:55:14              186  Reconyx
# 31389              Auto  2016:01:12 17:55:14              186  Reconyx
# 31390              Auto  2016:01:12 17:55:15              186  Reconyx
# 31391              Auto  2016:01:12 17:55:16              186  Reconyx
# 31392              Auto  2016:01:12 17:55:17              186  Reconyx
# 31393              Auto  2016:01:12 17:55:29              186  Reconyx
# 31394              Auto  2016:01:12 17:55:30              186  Reconyx
# 31395              Auto  2016:01:12 17:55:31              186  Reconyx
# 31396              Auto  2016:01:12 17:55:32              186  Reconyx
# 31397              Auto  2016:01:12 17:55:33              186  Reconyx
# 31398              Auto  2016:01:12 17:55:34              186  Reconyx
# 31399              Auto  2016:01:12 17:55:40              186  Reconyx
# 31400              Auto  2016:01:12 17:55:41              186  Reconyx
# 31401              Auto  2016:01:12 17:55:42              186  Reconyx
# 31402              Auto  2016:01:12 17:55:44              186  Reconyx
# 31403              Auto  2016:01:12 17:55:45              186  Reconyx
# 31404              Auto  2016:01:12 17:55:46              186  Reconyx
# 31405              Auto  2016:01:12 17:55:47              186  Reconyx
# 31406              Auto  2016:01:12 17:55:48              186  Reconyx
# 31407              Auto  2016:01:12 17:55:48              186  Reconyx
# 31408              Auto  2016:01:12 17:55:58              186  Reconyx
# 31409              Auto  2016:01:12 17:55:59              186  Reconyx
# 31410              Auto  2016:01:12 17:56:00              186  Reconyx
# 31411              Auto  2016:01:12 17:56:01              186  Reconyx
# 31412              Auto  2016:01:12 17:56:02              186  Reconyx
# 31413              Auto  2016:01:12 17:56:03              186  Reconyx
# 31414              Auto  2016:01:12 17:56:04              186  Reconyx
#
#           Image Model Image ResolutionUnit Image XResolution  \
# 0                 NaN          Pixels/Inch                72
# 1                 NaN          Pixels/Inch                72
# 2                 NaN          Pixels/Inch                72
# 3                 NaN          Pixels/Inch                72
# 4                 NaN          Pixels/Inch                72
# 5                 NaN          Pixels/Inch                72
# 6                 NaN          Pixels/Inch                72
# 7                 NaN          Pixels/Inch                72
# 8                 NaN          Pixels/Inch                72
# 9                 NaN          Pixels/Inch                72
# 10                NaN          Pixels/Inch                72
# 11                NaN          Pixels/Inch                72
# 12                NaN          Pixels/Inch                72
# 13                NaN          Pixels/Inch                72
# 14                NaN          Pixels/Inch                72
# 15                NaN          Pixels/Inch                72
# 16                NaN          Pixels/Inch                72
# 17                NaN          Pixels/Inch                72
# 18                NaN          Pixels/Inch                72
# 19                NaN          Pixels/Inch                72
# 20                NaN          Pixels/Inch                72
# 21                NaN          Pixels/Inch                72
# 22                NaN          Pixels/Inch                72
# 23                NaN          Pixels/Inch                72
# 24                NaN          Pixels/Inch                72
# 25                NaN          Pixels/Inch                72
# 26                NaN          Pixels/Inch                72
# 27                NaN          Pixels/Inch                72
# 28                NaN          Pixels/Inch                72
# 29                NaN          Pixels/Inch                72
# ...               ...                  ...               ...
# 31385  RM45 RAPIDFIRE          Pixels/Inch                72
# 31386  RM45 RAPIDFIRE          Pixels/Inch                72
# 31387  RM45 RAPIDFIRE          Pixels/Inch                72
# 31388  RM45 RAPIDFIRE          Pixels/Inch                72
# 31389  RM45 RAPIDFIRE          Pixels/Inch                72
# 31390  RM45 RAPIDFIRE          Pixels/Inch                72
# 31391  RM45 RAPIDFIRE          Pixels/Inch                72
# 31392  RM45 RAPIDFIRE          Pixels/Inch                72
# 31393  RM45 RAPIDFIRE          Pixels/Inch                72
# 31394  RM45 RAPIDFIRE          Pixels/Inch                72
# 31395  RM45 RAPIDFIRE          Pixels/Inch                72
# 31396  RM45 RAPIDFIRE          Pixels/Inch                72
# 31397  RM45 RAPIDFIRE          Pixels/Inch                72
# 31398  RM45 RAPIDFIRE          Pixels/Inch                72
# 31399  RM45 RAPIDFIRE          Pixels/Inch                72
# 31400  RM45 RAPIDFIRE          Pixels/Inch                72
# 31401  RM45 RAPIDFIRE          Pixels/Inch                72
# 31402  RM45 RAPIDFIRE          Pixels/Inch                72
# 31403  RM45 RAPIDFIRE          Pixels/Inch                72
# 31404  RM45 RAPIDFIRE          Pixels/Inch                72
# 31405  RM45 RAPIDFIRE          Pixels/Inch                72
# 31406  RM45 RAPIDFIRE          Pixels/Inch                72
# 31407  RM45 RAPIDFIRE          Pixels/Inch                72
# 31408  RM45 RAPIDFIRE          Pixels/Inch                72
# 31409  RM45 RAPIDFIRE          Pixels/Inch                72
# 31410  RM45 RAPIDFIRE          Pixels/Inch                72
# 31411  RM45 RAPIDFIRE          Pixels/Inch                72
# 31412  RM45 RAPIDFIRE          Pixels/Inch                72
# 31413  RM45 RAPIDFIRE          Pixels/Inch                72
# 31414  RM45 RAPIDFIRE          Pixels/Inch                72
#
#       Image YCbCrPositioning Image YResolution
# 0                   Co-sited                72
# 1                   Co-sited                72
# 2                   Co-sited                72
# 3                   Co-sited                72
# 4                   Co-sited                72
# 5                   Co-sited                72
# 6                   Co-sited                72
# 7                   Co-sited                72
# 8                   Co-sited                72
# 9                   Co-sited                72
# 10                  Co-sited                72
# 11                  Co-sited                72
# 12                  Co-sited                72
# 13                  Co-sited                72
# 14                  Co-sited                72
# 15                  Co-sited                72
# 16                  Co-sited                72
# 17                  Co-sited                72
# 18                  Co-sited                72
# 19                  Co-sited                72
# 20                  Co-sited                72
# 21                  Co-sited                72
# 22                  Co-sited                72
# 23                  Co-sited                72
# 24                  Co-sited                72
# 25                  Co-sited                72
# 26                  Co-sited                72
# 27                  Co-sited                72
# 28                  Co-sited                72
# 29                  Co-sited                72
# ...                      ...               ...
# 31385               Co-sited                72
# 31386               Co-sited                72
# 31387               Co-sited                72
# 31388               Co-sited                72
# 31389               Co-sited                72
# 31390               Co-sited                72
# 31391               Co-sited                72
# 31392               Co-sited                72
# 31393               Co-sited                72
# 31394               Co-sited                72
# 31395               Co-sited                72
# 31396               Co-sited                72
# 31397               Co-sited                72
# 31398               Co-sited                72
# 31399               Co-sited                72
# 31400               Co-sited                72
# 31401               Co-sited                72
# 31402               Co-sited                72
# 31403               Co-sited                72
# 31404               Co-sited                72
# 31405               Co-sited                72
# 31406               Co-sited                72
# 31407               Co-sited                72
# 31408               Co-sited                72
# 31409               Co-sited                72
# 31410               Co-sited                72
# 31411               Co-sited                72
# 31412               Co-sited                72
# 31413               Co-sited                72
# 31414               Co-sited                72
#
# [31415 rows x 25 columns]
